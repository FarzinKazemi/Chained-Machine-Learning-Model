# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score as acc
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
import math
from sklearn import model_selection
import os
import torch
from torch import nn
torch.manual_seed(3)
torch.cuda.manual_seed_all(3)

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
# Defining modle metrics, will be used in the end
from sklearn.metrics import r2_score
def R2(y_true, y_pred):
    return r2_score(y_true, y_pred)
from sklearn.metrics import mean_squared_log_error
def MSLE(y_true, y_pred):
    return mean_squared_log_error(y_true, y_pred)
from sklearn.metrics import explained_variance_score
def EX_VAR(y_true, y_pred):
    return explained_variance_score(y_true, y_pred)
from sklearn.metrics import mean_absolute_error
def MAE(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred)
from sklearn.metrics import mean_squared_error
def RMSE(y_true, y_pred):
    return mean_squared_error(y_true, y_pred,squared=True)
def MAP(y_true, y_pred):
    error=0
    for yt, yp in zip(y_true, y_pred):
        error += (yt - yp) / yt
    return (error / len(y_true))*100

# %%
#Reading the data and droping a useless column and droping all rows with Nan values in any column
#Scenario V-Modified.xlsx
DataSet = pd.read_excel( 'Dataset.xlsx').drop(columns=['name','DOI','content (%)', 'concrete elastic modulus(GPa)',
                                                          'Ductility index(deltap/deltay)','steel fiber type' ]).dropna()
# If necesasry yse the followings:

# Making one hot encoding of a column
#data = pd.get_dummies(data=DataSet, columns=['steel fiber type'])
#data = data.drop(columns = ['Soil Type_Fissured'])
#data = data[data['Soil Type_Intact']>0]


# adding a new column with name Kfold, later we will use it 
data = DataSet.copy()

# scaling
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data.values), index=data.index, columns=data.columns)

data['kfold'] = -1
print(data.columns)
print(len(data))
data.head(5)
# Out:
# Index(['fiber aspect ratio(mm/mm)', 'fiber density(g/cm3)',
#        'volume fraction(%)', 'reinforcement ratio(%)', 'beam width(mm)',
#        'beam height(mm)', 'beam length(mm)', 'shear span-depth ratio',
#        'fiber tensile strength(MPa)', 'Ductility index(deltau/deltay)',
#        'Max Load', 'Deltap', 'kfold'],
#       dtype='object')
# 184
# C:\Users\Fabagh001\Anaconda3\envs\FARAMARZ\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#    fiber aspect ratio(mm/mm)  fiber density(g/cm3)  volume fraction(%)  \
# 0                      0.000                   0.0            0.000000
# 1                      0.000                   0.0            0.000000
# 2                      0.650                   1.0            0.666667
# 3                      0.650                   1.0            0.666667
# 4                      0.975                   1.0            0.666667
#
#    reinforcement ratio(%)  beam width(mm)  beam height(mm)  beam length(mm)  \
# 0                0.132394            0.25         0.171429         0.571429
# 1                0.211268            0.25         0.171429         0.571429
# 2                0.132394            0.25         0.171429         0.571429
# 3                0.211268            0.25         0.171429         0.571429
# 4                0.132394            0.25         0.171429         0.571429
#
#    shear span-depth ratio  fiber tensile strength(MPa)  \
# 0                0.683333                     0.000000
# 1                0.683333                     0.000000
# 2                0.683333                     0.927787
# 3                0.683333                     0.927787
# 4                0.683333                     0.831947
#
#    Ductility index(deltau/deltay)  Max Load    Deltap  kfold
# 0                        0.390661  0.058660  0.522806     -1
# 1                        0.224125  0.098821  0.402627     -1
# 2                        0.159533  0.086762  0.153214     -1
# 3                        0.145525  0.128629  0.107881     -1
# 4                        0.159144  0.093588  0.164952     -1

# %%
len(data)
# Out:
# 184

# %%
#Random shuffling the data 
df = data.sample(frac= 1, random_state=10).reset_index(drop=True)

#Adding numbers for each fold of data to the Kfold column 
kf = model_selection.KFold(n_splits=5)
for fold, (trn_, val_) in enumerate(kf.split(X=df)):
    df.loc[val_, 'kfold'] = fold

# check the Kfold column, now we can select a scpecific chunk of data with using Kfold column
df.head(3)
# Out:
#    fiber aspect ratio(mm/mm)  fiber density(g/cm3)  volume fraction(%)  \
# 0                       0.00              0.000000            0.000000
# 1                       0.45              0.987342            0.666667
# 2                       0.64              0.987342            0.253333
#
#    reinforcement ratio(%)  beam width(mm)  beam height(mm)  beam length(mm)  \
# 0                0.126761           0.125         0.214286         0.714286
# 1                0.098592           0.250         0.071429         0.200000
# 2                0.021127           0.700         0.285714         0.771429
#
#    shear span-depth ratio  fiber tensile strength(MPa)  \
# 0                0.516667                     0.407654
# 1                0.258333                     0.366057
# 2                0.321667                     0.447587
#
#    Ductility index(deltau/deltay)  Max Load    Deltap  kfold
# 0                        0.052529  0.086989  0.090833      0
# 1                        0.112840  0.076181  0.036333      0
# 2                        0.140078  0.032948  0.127446      0

# %%
# for ANN we use CPU of computer, so no need for GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# Define Pytorch model
# This model has 3 layers. if you need more layer you should first define the layer in "__init__" function
# then use the layer in "forward" function

class TinyModel(torch.nn.Module):

    def __init__(self,n_inputs, l1, l2,l3, n_outputs):
        
        super(TinyModel, self).__init__()

        self.linear1 = torch.nn.Linear(n_inputs, l1)
        self.activation = torch.nn.ReLU()
        self.linear2 = torch.nn.Linear(l1, l2)
        self.linear3 = torch.nn.Linear(l2, l3)
        self.linear4 = torch.nn.Linear(l3, n_outputs)
        #self.softmax = torch.nn.Softmax() use it if necessary (use it for classification task)

    def forward(self, x):
        x = self.linear1(x)
        x = self.activation(x)
        x = self.linear2(x)
        x = self.activation(x)
        x = self.linear3(x)
        x = self.activation(x)
        x = self.linear4(x)

        return x
# Out:
# Using cuda device

# %%
# hyperparameters for making a model

def creat_model():
    # check number of inputs and outputs    
    n_inputs = 9
    n_outputs = 3
    
    # build the model with given hyperparameters    
    model = TinyModel(n_inputs,64,128,256,n_outputs)
    
    print(model)
    return model

def start_training():
    #Compiling the model
    epochs = 200
    model = creat_model()
    
    #chose the proper loss function
    loss_fn = nn.L1Loss()
    #loss_fn = nn.MSELoss()
    
    #chose the proper optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    #optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
    
    print(model)
    
    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")
        train(x_train, y_train, model, loss_fn, optimizer)
        test(x_test, y_test, model, loss_fn)
    return model

# %%
def train(X,y, model, loss_fn, optimizer):
    # Change X and Y to Pytorch arrays
    X= torch.tensor(X.values, dtype = torch.float)
    y= torch.tensor(y.values, dtype = torch.float)
    model.train()

    # Compute prediction error
    pred = model(X)
    #y = torch.reshape(y,(list(y.size())[0],1))
    print(pred.shape)
    print(y.shape)
    loss = loss_fn(pred, y)
        # Backpropagation
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
def test(X,y, model, loss_fn):
    X= torch.tensor(X.values, dtype = torch.float)
    y= torch.tensor(y.values, dtype = torch.float)
    with torch.no_grad():
        pred = model(X)
        print(R2(pred.numpy(),y.numpy()))
    return

# %%
targets = ['Ductility index(deltau/deltay)','Max Load', 'Deltap','kfold']
inputs = [x for x in data.columns if x not in targets]
inputs.append('kfold')
print (inputs)
# Out:
# ['fiber aspect ratio(mm/mm)', 'fiber density(g/cm3)', 'volume fraction(%)', 'reinforcement ratio(%)', 'beam width(mm)', 'beam height(mm)', 'beam length(mm)', 'shear span-depth ratio', 'fiber tensile strength(MPa)', 'kfold']

# %%
list_train, list_test = [] ,[]
list_R2_train, list_R2_test = [] ,[]
list_RMSE_train, list_RMSE_test = [],[]
list_MAE_train, list_MAE_test = [] ,[]
list_MAP_train, list_MAP_test =[] ,[]

# it is used for MinMax scale back to original values
#Mm =DataSet['OCR'].max() - DataSet['OCR'].min()

for i in range(5):
    # calling a fold and getting the X and Y for that fold
    test_fold = i
    x_train = df[df['kfold']!= test_fold].drop(columns= targets)
    y_train = df[df['kfold']!= test_fold].drop(columns = inputs)
    x_test = df[df['kfold']== test_fold].drop(columns= targets)
    y_test = df[df['kfold']== test_fold].drop(columns = inputs)
    
    model = start_training()
#'''    
    # changing to Pytorch tensors for calculating model metrics
    x_train= torch.tensor(x_train.values, dtype = torch.float)
    x_test= torch.tensor(x_test.values, dtype = torch.float)
    
    # calling the model and making prediction
    y_pred_train = model(x_train).detach().numpy()
    y_pred_test  = model(x_test).detach().numpy()

    
    # saving the whol model output in each fold (becarefull about memory capacity)
    list_train.append((y_train,y_pred_train))
    list_test.append((y_test,y_pred_test))

    
    # saving the model metrics of each FOLD in a list
    list_R2_test.append(R2(y_test,y_pred_test))
    list_R2_train.append(R2(y_train,y_pred_train))
    
    list_RMSE_test.append(RMSE(y_test,y_pred_test))
    list_RMSE_train.append(RMSE(y_train,y_pred_train))
    
    list_MAE_test.append(MAE(y_test,y_pred_test))
    list_MAE_train.append(MAE(y_train,y_pred_train))
    

    #scale back if needed (only for single output)
    
    #y_pred_train = (y_pred_train * Mm) + DataSet['OCR'].min()
    #y_pred_test = (y_pred_test * Mm) + DataSet['OCR'].min()
    
    #y_train = (y_train * Mm) + DataSet['OCR'].min()
    #y_test = (y_test * Mm) + DataSet['OCR'].min()
# Out:
# TinyModel(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (activation): ReLU()
#   (linear2): Linear(in_features=64, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (linear4): Linear(in_features=256, out_features=3, bias=True)
# )
# TinyModel(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (activation): ReLU()
#   (linear2): Linear(in_features=64, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (linear4): Linear(in_features=256, out_features=3, bias=True)
# )
# Epoch 1
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -339.25198730762855
# Epoch 2
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -149.40872911058074
# Epoch 3
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -68.7031023907273
# Epoch 4
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -38.94387904072689
# Epoch 5
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -28.57657666461611
# Epoch 6
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -26.298340817382154
# Epoch 7
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -26.975515742815162
# Epoch 8
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -29.280596598938406
# Epoch 9
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -32.92828619621839
# Epoch 10
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -38.111301768658926
# Epoch 11
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -44.2131790942418
# Epoch 12
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -50.81626766318553
# Epoch 13
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -56.92162228825216
# Epoch 14
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
#
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.29380642564862475
# Epoch 195
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2916233391452519
# Epoch 196
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.30508434994118533
# Epoch 197
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2986104625052716
# Epoch 198
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.28346190266048416
# Epoch 199
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2744631100180032
# Epoch 200
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2836543057525796
# TinyModel(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (activation): ReLU()
#   (linear2): Linear(in_features=64, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (linear4): Linear(in_features=256, out_features=3, bias=True)
# )
# TinyModel(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (activation): ReLU()
#   (linear2): Linear(in_features=64, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (linear4): Linear(in_features=256, out_features=3, bias=True)
# )
# Epoch 1
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -953.2866309882608
# Epoch 2
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -527.587090926744
# Epoch 3
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -280.49711824437884
# Epoch 4
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -172.54296617932144
# Epoch 5
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -128.44512568780067
# Epoch 6
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -112.0601294166518
# Epoch 7
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -109.80017640242357
# Epoch 8
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -115.55469304097393
# Epoch 9
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -125.02778392102653
# Epoch 10
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -125.85246397715969
# Epoch 11
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -113.65206942942159
# Epoch 12
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -95.30717531372538
# Epoch 13
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -79.00665830303
# Epoch 14
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -67.27777948473482
# Epoch 15
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -58.14601054314222
# Epoch 16
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -50.71399816205595
# Epoch 17
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -44.6148870346305
# Epoch 18
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -39.1298670210142
# Epoch 19
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -34.23396390295819
# Epoch 20
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -30.199221883916994
# Epoch 21
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -27.063822740640386
# Epoch 22
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -24.58376086794712
# Epoch 23
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -22.56892748999189
# Epoch 24
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -20.83152389536544
# Epoch 25
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -19.17657953900321
# Epoch 26
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -17.578416492506882
# Epoch 27
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -15.977933593294571
# Epoch 28
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -14.412913812463884
# Epoch 29
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -13.025958625387714
# Epoch 30
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -11.792714238817233
# Epoch 31
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -10.547836332928549
# Epoch 32
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -9.239497370978697
# Epoch 33
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -7.995816848073139
# Epoch 34
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -6.94521803711973
# Epoch 35
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -6.0152119447150065
# Epoch 36
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -5.203257414981604
# Epoch 37
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -4.540491408231656
# Epoch 38
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -4.12003669143041
# Epoch 39
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -3.8252703884440424
# Epoch 40
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -3.630881992435804
# Epoch 41
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -3.5219044975996177
# Epoch 42
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -3.423382707591053
# Epoch 43
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -3.283603542644272
# Epoch 44
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -3.08143884303855
# Epoch 45
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.8607078741372405
# Epoch 46
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.7180766588694976
# Epoch 47
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.514171250747779
# Epoch 48
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.401259147411186
# Epoch 49
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.4714797525283316
# Epoch 50
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.486184826047665
# Epoch 51
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.4441110006687405
# Epoch 52
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.4124765852961594
# Epoch 53
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.3800536693786287
# Epoch 54
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.1875244780821883
# Epoch 55
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -2.0050977443737286
# Epoch 56
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.926859764119646
# Epoch 57
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.8700393696705078
# Epoch 58
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.7793342570118584
# Epoch 59
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.7080840736503207
# Epoch 60
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.6141292237072886
# Epoch 61
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.4829747096578767
# Epoch 62
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.3836077025557103
# Epoch 63
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.3141041572667536
# Epoch 64
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.240536797704012
# Epoch 65
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.1323788081714632
# Epoch 66
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.0776705263802953
# Epoch 67
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1.0274391658072795
# Epoch 68
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.9864882136290071
# Epoch 69
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.9780301568564814
# Epoch 70
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.8652235874221047
# Epoch 71
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.8586415684195391
# Epoch 72
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.8256868696964617
# Epoch 73
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.7347848346927233
# Epoch 74
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.6803316476872133
# Epoch 75
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0.6705090451891108
# Epoch 76
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -0
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.16009791121814979
# Epoch 170
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2134314731726353
# Epoch 171
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.17416947677257533
# Epoch 172
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.17077561528512716
# Epoch 173
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.20282864920424515
# Epoch 174
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.15301336308836042
# Epoch 175
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.1459037147148294
# Epoch 176
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.20617828078136954
# Epoch 177
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.17436109490023932
# Epoch 178
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.1662292201331668
# Epoch 179
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.22399860381801764
# Epoch 180
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.1888213789036901
# Epoch 181
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.16917952767757935
# Epoch 182
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.20330183542359423
# Epoch 183
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.1966225206750255
# Epoch 184
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.15497652637295825
# Epoch 185
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2114299094213248
# Epoch 186
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.18547870945623815
# Epoch 187
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.1584154839808706
# Epoch 188
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.20890915947889577
# Epoch 189
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.18339829282875197
# Epoch 190
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.16657857361048012
# Epoch 191
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.19555381518845705
# Epoch 192
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2017725196841167
# Epoch 193
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.20422494616239825
# Epoch 194
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.20679697885550583
# Epoch 195
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.2266256373598431
# Epoch 196
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.17410117384026655
# Epoch 197
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.21392738086543028
# Epoch 198
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.21688206059948137
# Epoch 199
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.1909871147268769
# Epoch 200
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# 0.18537115476037005
# TinyModel(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (activation): ReLU()
#   (linear2): Linear(in_features=64, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (linear4): Linear(in_features=256, out_features=3, bias=True)
# )
# TinyModel(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (activation): ReLU()
#   (linear2): Linear(in_features=64, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (linear4): Linear(in_features=256, out_features=3, bias=True)
# )
# Epoch 1
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -1002.0967216717798
# Epoch 2
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -315.1695728694108
# Epoch 3
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -114.17332436933468
# Epoch 4
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -52.24365225223505
# Epoch 5
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -33.91417810790159
# Epoch 6
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -28.939579730037433
# Epoch 7
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -29.631846776045695
# Epoch 8
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -34.33389767018519
# Epoch 9
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -43.18009550128968
# Epoch 10
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -57.1596016074426
# Epoch 11
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -73.88398746880412
# Epoch 12
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -87.53711964354882
# Epoch 13
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -92.9783494085484
# Epoch 14
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -89.50711112390104
# Epoch 15
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -79.9031724222556
# Epoch 16
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -68.84517325088017
# Epoch 17
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -58.55740911051743
# Epoch 18
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -50.009128827634434
# Epoch 19
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -43.46903144490008
# Epoch 20
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -38.226072923196
# Epoch 21
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -34.33929116010211
# Epoch 22
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -31.74794312774959
# Epoch 23
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -30.651319118933767
# Epoch 24
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -30.508111378122237
# Epoch 25
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -30.312315452190177
# Epoch 26
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -29.176637386543565
# Epoch 27
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -27.343070372246686
# Epoch 28
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -24.969246469560858
# Epoch 29
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -22.174786356236435
# Epoch 30
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -19.29057976680067
# Epoch 31
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -17.02837407280656
# Epoch 32
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -15.36010694064891
# Epoch 33
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -14.07076844097678
# Epoch 34
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -13.062995949092814
# Epoch 35
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -12.208437976963557
# Epoch 36
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -11.445561105007783
# Epoch 37
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -10.715533501774047
# Epoch 38
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -10.068411419222215
# Epoch 39
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -9.346973548627881
# Epoch 40
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -8.766010044018506
# Epoch 41
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -8.270487071086777
# Epoch 42
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -7.868418494837634
# Epoch 43
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -7.558254270138941
# Epoch 44
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -7.285200476744329
# Epoch 45
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -7.090916152324656
# Epoch 46
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -6.933464674619523
# Epoch 47
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -6.638540231699422
# Epoch 48
# -------------------------------
# torch.Size([147, 3])
# torch.Size([147, 3])
# -6.268681447754832
# Epoch 49
# -------------------------------
# torch.Size([147, 3])
# ...
# torch.Size([148, 3])
# torch.Size([148, 3])
# -4
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.1498876995015369
# Epoch 134
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.1115120714040458
# Epoch 135
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.14035716602791126
# Epoch 136
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.14646110761370199
# Epoch 137
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.11371994712320543
# Epoch 138
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.13680800047925532
# Epoch 139
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.13528118022152688
# Epoch 140
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.08421079787301751
# Epoch 141
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.06775204343302155
# Epoch 142
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.09576984361004315
# Epoch 143
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.07978373270856869
# Epoch 144
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.034197018870735084
# Epoch 145
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.015028735917235525
# Epoch 146
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.03305958140916343
# Epoch 147
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# -0.01117896876984903
# Epoch 148
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.026114409356762385
# Epoch 149
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.02340126815562386
# Epoch 150
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.028378957677450356
# Epoch 151
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.061947919145440844
# Epoch 152
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.063347651213292
# Epoch 153
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.07568312903818948
# Epoch 154
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.11937969277694223
# Epoch 155
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.14037116023588894
# Epoch 156
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.13176211816852446
# Epoch 157
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.13530273981585664
# Epoch 158
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.1566147246570401
# Epoch 159
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.15800900182649344
# Epoch 160
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.1578367459288831
# Epoch 161
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.173316569693552
# Epoch 162
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.15392350524717888
# Epoch 163
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.18360758070691696
# Epoch 164
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.19455911982395188
# Epoch 165
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.20684250618236202
# Epoch 166
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.23652482163146463
# Epoch 167
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.2305787156605409
# Epoch 168
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.2403349939466399
# Epoch 169
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.22375077388896472
# Epoch 170
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.2540628701129099
# Epoch 171
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.26958244912262613
# Epoch 172
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.26045985826597506
# Epoch 173
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.254434482534212
# Epoch 174
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.24472369261083263
# Epoch 175
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.27823815547180275
# Epoch 176
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.284820415099317
# Epoch 177
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.28839687889376187
# Epoch 178
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.29861877289482486
# Epoch 179
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.28268965959328524
# Epoch 180
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3044997583899367
# Epoch 181
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3189185134756887
# Epoch 182
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.30905080350351394
# Epoch 183
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3189013650883638
# Epoch 184
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3475279076647391
# Epoch 185
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3484210730245481
# Epoch 186
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3270760690247398
# Epoch 187
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3448451088051683
# Epoch 188
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.36699502533466005
# Epoch 189
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.37217449876667646
# Epoch 190
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.36069295348716074
# Epoch 191
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.36274672924670653
# Epoch 192
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.37187357677782035
# Epoch 193
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3731701594797734
# Epoch 194
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3733599268618768
# Epoch 195
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.38336839967556885
# Epoch 196
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.3774597736059329
# Epoch 197
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.4015667642315874
# Epoch 198
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.42103749225166553
# Epoch 199
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.4112966939594231
# Epoch 200
# -------------------------------
# torch.Size([148, 3])
# torch.Size([148, 3])
# 0.40673143342169166

# %%
print('Neural Network')
print('  ')
print('%%% TEST %%%')
print('R2 = ',round(np.mean(list_R2_test),3))
print('RMSE = ',round(np.mean(list_RMSE_test),2))
print('MAE = ',round(np.mean(list_MAE_test),2))

#print(np.mean(list_R2_test))
print('  ')
print('*** TRAIN ***')
print('R2 = ',round(np.mean(list_R2_train),3))
print('RMSE = ',round(np.mean(list_RM0.04SE_train),2))
print('MAE = ',round(np.mean(list_MAE_train),2))

#print(np.mean(list_R2_test))
# Out:
# Neural Network
#
# %%% TEST %%%
# R2 =  0.595
# RMSE =  0.01
# MAE =  0.06
#
# *** TRAIN ***
# R2 =  0.718
# RMSE =  0.01
# MAE =  0.04
